# %%
#from Week_4 import G
import networkx as nx
G = nx.read_gpickle("css_graph.gpickle")

# %% [markdown]
# # Part 1: Centrality and Assortativity

# %% [markdown]
# # Exercise 1: Mixing Patterns and Assortativity.

# %%
import netwulf as nw
import matplotlib.pyplot as plt
import numpy as np
import random
import matplotlib.colors as mcolors
import math
import statistics
import random
from scipy.stats import ttest_1samp

# %%
#Make all missing top_fields = None
for author in G.nodes:
    if 'top_field' not in G.nodes[author]:
        G.nodes[author]['top_field'] = None

# %%
#Compute average neighboors in same top field as each node
def network_mean_same_field(top_fild_name):
    for author in G.nodes:
        G.nodes[author]['Avr_same_field'] = mean_same_field = statistics.mean(map(int, [G.nodes[author][top_fild_name] == field for field 
              in [G.nodes[neighboor][top_fild_name] for neighboor 
                  in G.neighbors(author)]]))
    
    #network average
    network_mean = statistics.mean(map(float, [G.nodes[author]['Avr_same_field'] for author in G.nodes]))
    return network_mean

network_mean = network_mean_same_field('top_field')

# %%
top_fields = list(nx.get_node_attributes(G, "top_field").values())

def randomise_top_fields_rand():
    random.shuffle(top_fields)
    for i, author in enumerate(G.nodes):
        G.nodes[author]['top_field_rand'] = top_fields[i]

# %%
#Compute average neighboors in same top field as each node 100 times for random top fields
rand_means = [] 
for i in range(100):
    randomise_top_fields_rand()
    rand_means.append(network_mean_same_field('top_field_rand'))
    
#rand_means

# %%
#compute the p-value for the null-hypothesis that out network mean occured by random... The p-value is extreemly low
t_stat, p_value = ttest_1samp(rand_means, network_mean)
p_value
# Out:
# 8.651100805299486e-90

# %%
#assortativity_coefficient wrt. field
nx.attribute_assortativity_coefficient(G, 'top_field')
#The positive value of r indicates that authors with the same top field are more likely to connect to each other 
#than to authors with the same top fields
# Out:
# 0.19736071416782391

# %%
#assortativity_coefficient wrt. degree (default)
nx.degree_assortativity_coefficient(G)
#The positive value of r mean s taht the network is aasortative wrt degree i.e. authors with similar degrees are more likely to connect to each other 
#than to authors with differetn degrees
# Out:
# 0.3570643745412559

# %% [markdown]
# # Exercise 2: Central nodes.

# %%
close_centrals = nx.closeness_centrality(G)
top_ClosCentr = sorted(close_centrals.items(), key=lambda x: x[1], reverse=True)[:5]
top_ClosCentr
#We imagine that the scientists with a high closeness centrality have are very well connected, maybe they work in positions with many collaborative papers.
# Out:
# [('1682773', 0.016899441340782122),
#  ('8311574', 0.015279568352194052),
#  ('2836702', 0.015048059740797173),
#  ('2856607', 0.014202949957139903),
#  ('5164568', 0.014202949957139903)]

# %%
eigenvector = nx.eigenvector_centrality(G, max_iter = 2000)
top_eigenvector = sorted(eigenvector.items(), key=lambda x: x[1], reverse=True)[:5]
print("Top 5 scientists by eigenvector centrality:")
for node, centrality in top_eigenvector:
    print(node, centrality)
# Out:
# Top 5 scientists by eigenvector centrality:
# 1805055 0.36300538986992037
# 51901315 0.33772819910981333
# 35410873 0.3377281991098133
# 2101022236 0.3377281991098133
# 26401957 0.25497096664038343

# %%
degree = dict(G.degree())
plt.scatter(list(degree.values()),list(close_centrals.values()), alpha=0.1)
plt.xlabel('Degree')
plt.ylabel('Closeness Centrality')
plt.show()

# %%
plt.scatter(list(degree.values()),list(eigenvector.values()), alpha=0.1)
plt.xlabel('Degree')
plt.ylabel('Eigenvector Centrality')
plt.show()
#there does not seem to be much of a correlation, i.e. your number of neighboors does not semm to dictate how central they are in the network.

# %%
plt.scatter(list(degree.values()),list(eigenvector.values()), alpha=0.1)
plt.xlabel('Degree')
plt.ylabel('Eigenvector Centrality')
plt.yscale("log")
plt.show()
#there does not seem to be much of a correlation, i.e. your number of neighboors does not semm to dictate how central they are in the network.

# %% [markdown]
# Even with the logscale, I suspect that the small correlation that we see is simply a function of the minimum poosible value depending on the degree, for all the nodes that have a very low score.

# %% [markdown]
# # Part 2: Community detection

# %%
import matplotlib.pyplot as plt
import networkx as nx
import netwulf as nw

G = nx.karate_club_graph()

# Define colors for each club
club_colors = {'Mr. Hi': 'red', 'Officer': 'blue'}

# Get node colors based on club attribute
node_colors = [club_colors[G.nodes[n]['club']] for n in G.nodes()]

# Draw the graph with node colors
nx.draw_networkx(G, with_labels=True, node_color=node_colors)

# Show the plot
plt.show()

# %%
import netwulf as nw
nx.set_node_attribute()
nw.visualize(G)
# Out:
# ({'xlim': [0, 731],
#   'ylim': [0, 731],
#   'linkColor': '#7c7c7c',
#   'linkAlpha': 0.5,
#   'nodeStrokeColor': '#555555',
#   'nodeStrokeWidth': 1,
#   'links': [{'source': 0,
#     'target': 1,
#     'width': 1.5118578920369088,
#     'weight': 4},
#    {'source': 0, 'target': 2, 'width': 1.6903085094570331, 'weight': 5},
#    {'source': 0, 'target': 3, 'width': 1.3093073414159542, 'weight': 3},
#    {'source': 0, 'target': 4, 'width': 1.3093073414159542, 'weight': 3},
#    {'source': 0, 'target': 5, 'width': 1.3093073414159542, 'weight': 3},
#    {'source': 0, 'target': 6, 'width': 1.3093073414159542, 'weight': 3},
#    {'source': 0, 'target': 7, 'width': 1.0690449676496976, 'weight': 2},
#    {'source': 0, 'target': 8, 'width': 1.0690449676496976, 'weight': 2},
#    {'source': 0, 'target': 10, 'width': 1.0690449676496976, 'weight': 2},
#    {'source': 0, 'target': 11, 'width': 1.3093073414159542, 'weight': 3},
#    {'source': 0, 'target': 12, 'width': 0.7559289460184544, 'weight': 1},
#    {'source': 0, 'target': 13, 'width': 1.3093073414159542, 'weight': 3},
#    {'source': 0, 'target': 17, 'width': 1.0690449676496976, 'weight': 2},
#    {'source': 0, 'target': 19, 'width': 1.0690449676496976, 'weight': 2},
#    {'source': 0, 'target': 21, 'width': 1.0690449676496976, 'weight': 2},
#    {'source': 0, 'target': 31, 'width': 1.0690449676496976, 'weight': 2},
#    {'source': 1, 'target': 2, 'width': 1.8516401995451026, 'weight': 6},
#    {'source': 1, 'target': 3, 'width': 1.3093073414159542, 'weight': 3},
#    {'source': 1, 'target': 7, 'width': 1.5118578920369088, 'weight': 4},
#    {'source': 1, 'target': 13, 'width': 1.6903085094570331, 'weight': 5},
#    {'source': 1, 'target': 17, 'width': 0.7559289460184544, 'weight': 1},
#    {'source': 1, 'target': 19, 'width': 1.0690449676496976, 'weight': 2},
#    {'source': 1, 'target': 21, 'width': 1.0690449676496976, 'weight': 2},
#    {'source': 1, 'target': 30, 'width': 1.0690449676496976, 'weight': 2},
#    {'source': 2, 'target': 3, 'width': 1.3093073414159542, 'weight': 3},
#    {'source': 2, 'target': 7, 'width': 1.5118578920369088, 'weight': 4},
#    {'source': 2, 'target': 8, 'width': 1.6903085094570331, 'weight': 5},
#    {'source': 2, 'target': 9, 'width': 0.7559289460184544, 'weight': 1},
#    {'source': 2, 'target': 13, 'width': 1.3093073414159542, 'weight': 3},
#    {'source': 2, 'target': 27, 'width': 1.0690449676496976, 'weight': 2},
#    {'source': 2, 'target': 28, 'width': 1.0690449676496976, 'weight': 2},
#    {'source': 2, 'target': 32, 'width': 1.0690449676496976, 'weight': 2},
#    {'source': 3, 'target': 7, 'width': 1.3093073414159542, 'weight': 3},
#    {'source': 3, 'target': 12, 'width': 1.3093073414159542, 'weight': 3},
#    {'source': 3, 'target': 13, 'width': 1.3093073414159542, 'weight': 3},
#    {'source': 4, 'target': 6, 'width': 1.0690449676496976, 'weight': 2},
#    {'source': 4, 'target': 10, 'width': 1.3093073414159542, 'weight': 3},
#    {'source': 5, 'target': 6, 'width': 1.6903085094570331, 'weight': 5},
#    {'source': 5, 'target': 10, 'width': 1.3093073414159542, 'weight': 3},
#    {'source': 5, 'target': 16, 'width': 1.3093073414159542, 'weight': 3},
#    {'source': 6, 'target': 16, 'width': 1.3093073414159542, 'weight': 3},
#    {'source': 8, 'target': 30, 'width': 1.3093073414159542, 'weight': 3},
#    {'source': 8, 'target': 32, 'width': 1.3093073414159542, 'weight': 3},
#    {'source': 8, 'target': 33, 'width': 1.5118578920369088, 'weight': 4},
#    {'source': 9, 'target': 33, 'width': 1.0690449676496976, 'weight': 2},
#    {'source': 13, 'target': 33, 'width': 1.3093073414159542, 'weight': 3},
#    {'source': 14, 'target': 32, 'width': 1.3093073414159542, 'weight': 3},
#    {'source': 14, 'target': 33, 'width': 1.0690449676496976, 'weight': 2},
#    {'source': 15, 'target': 32, 'width': 1.3093073414159542, 'weight': 3},
#    {'source': 15, 'target': 33, 'width': 1.5118578920369088, 'weight': 4},
#    {'source': 18, 'target': 32, 'width': 0.7559289460184544, 'weight': 1},
#    {'source': 18, 'target': 33, 'width': 1.0690449676496976, 'weight': 2},
#    {'source': 19, 'target': 33, 'width': 0.7559289460184544, 'weight': 1},
#    {'source': 20, 'target': 32, 'width': 1.3093073414159542, 'weight': 3},
#    {'source': 20, 'target': 33, 'width': 0.7559289460184544, 'weight': 1},
#    {'source': 22, 'target': 32, 'width': 1.0690449676496976, 'weight': 2},
#    {'source': 22, 'target': 33, 'width': 1.3093073414159542, 'weight': 3},
#    {'source': 23, 'target': 25, 'width': 1.6903085094570331, 'weight': 5},
#    {'source': 23, 'target': 27, 'width': 1.5118578920369088, 'weight': 4},
#    {'source': 23, 'target': 29, 'width': 1.3093073414159542, 'weight': 3},
#    {'source': 23, 'target': 32, 'width': 1.6903085094570331, 'weight': 5},
#    {'source': 23, 'target': 33, 'width': 1.5118578920369088, 'weight': 4},
#    {'source': 24, 'target': 25, 'width': 1.0690449676496976, 'weight': 2},
#    {'source': 24, 'target': 27, 'width': 1.3093073414159542, 'weight': 3},
#    {'source': 24, 'target': 31, 'width': 1.0690449676496976, 'weight': 2},
#    {'source': 25, 'target': 31, 'width': 2, 'weight': 7},
#    {'source': 26, 'target': 29, 'width': 1.5118578920369088, 'weight': 4},
#    {'source': 26, 'target': 33, 'width': 1.0690449676496976, 'weight': 2},
#    {'source': 27, 'target': 33, 'width': 1.5118578920369088, 'weight': 4},
#    {'source': 28, 'target': 31, 'width': 1.0690449676496976, 'weight': 2},
#    {'source': 28, 'target': 33, 'width': 1.0690449676496976, 'weight': 2},
#    {'source': 29, 'target': 32, 'width': 1.5118578920369088, 'weight': 4},
#    {'source': 29, 'target': 33, 'width': 1.0690449676496976, 'weight': 2},
#    {'source': 30, 'target': 32, 'width': 1.3093073414159542, 'weight': 3},
#    {'source': 30, 'target': 33, 'width': 1.3093073414159542, 'weight': 3},
#    {'source': 31, 'target': 32, 'width': 1.5118578920369088, 'weight': 4},
#    {'source': 31, 'target': 33, 'width': 1.5118578920369088, 'weight': 4},
#    {'source': 32, 'target': 33, 'width': 1.6903085094570331, 'weight': 5}],
#   'nodes': [{'id': 0,
#     'x': 387.75982352968157,
#     'y': 403.4514623992934,
#     'x_canvas': 387.75982352968157,
#     'y_canvas': 403.45146239929335,
#     'radius': 5,
#     'color': '#79aaa0'},
#    {'id': 1,
#     'x': 333.5866239880849,
#     'y': 416.19272628465234,
#     'x_canvas': 333.5866239880849,
#     'y_canvas': 416.19272628465234,
#     'radius': 5,
#     'color': '#79aaa0'},
#    {'id': 2,
#     'x': 372.63587946477975,
#     'y': 372.86747612343515,
#     'x_canvas': 372.6358794647798,
#     'y_canvas': 372.86747612343515,
#     'radius': 5,
#     'color': '#79aaa0'},
#    {'id': 3,
#     'x': 362.34253052776285,
#     'y': 436.24115620188473,
#     'x_canvas': 362.34253052776285,
#     'y_canvas': 436.24115620188473,
#     'radius': 5,
#     'color': '#79aaa0'},
#    {'id': 4,
#     'x': 416.6564905007603,
#     'y': 411.36719482175505,
#     'x_canvas': 416.6564905007603,
#     'y_canvas': 411.36719482175505,
#     'radius': 5,
#     'color': '#79aaa0'},
#    {'id': 5,
#     'x': 437.7948635481892,
#     'y': 396.3500642796092,
#     'x_canvas': 437.79486354818926,
#     'y_canvas': 396.3500642796092,
#     'radius': 5,
#     'color': '#79aaa0'},
#    {'id': 6,
#     'x': 431.7948921407719,
#     'y': 421.8338589829705,
#     'x_canvas': 431.7948921407719,
#     'y_canvas': 421.83385898297047,
#     'radius': 5,
#     'color': '#79aaa0'},
#    {'id': 7,
#     'x': 361.4943982347632,
#     'y': 409.40075232133864,
#     'x_canvas': 361.4943982347632,
#     'y_canvas': 409.40075232133864,
#     'radius': 5,
#     'color': '#79aaa0'},
#    {'id': 8,
#     'x': 346.8191116425878,
#     'y': 367.8562072784249,
#     'x_canvas': 346.8191116425878,
#     'y_canvas': 367.85620727842496,
#     'radius': 5,
#     'color': '#79aaa0'},
#    {'id': 9,
#     'x': 363.40951784931417,
#     'y': 349.7036659657129,
#     'x_canvas': 363.40951784931417,
#     'y_canvas': 349.7036659657129,
#     'radius': 5,
#     'color': '#79aaa0'},
#    {'id': 10,
#     'x': 422.4609915014418,
#     'y': 384.7122054702433,
#     'x_canvas': 422.4609915014418,
#     'y_canvas': 384.71220547024336,
#     'radius': 5,
#     'color': '#79aaa0'},
#    {'id': 11,
#     'x': 404.19331492865405,
#     'y': 392.2412176161173,
#     'x_canvas': 404.19331492865405,
#     'y_canvas': 392.2412176161173,
#     'radius': 5,
#     'color': '#79aaa0'},
#    {'id': 12,
#     'x': 387.2407170466786,
#     'y': 435.95199318021645,
#     'x_canvas': 387.2407170466786,
#     'y_canvas': 435.95199318021645,
#     'radius': 5,
#     'color': '#79aaa0'},
#    {'id': 13,
#     'x': 359.1207235190111,
#     'y': 391.6841202365122,
#     'x_canvas': 359.1207235190111,
#     'y_canvas': 391.6841202365122,
#     'radius': 5,
#     'color': '#79aaa0'},
#    {'id': 14,
#     'x': 320.1022835283323,
#     'y': 352.9191435291148,
#     'x_canvas': 320.1022835283323,
#     'y_canvas': 352.9191435291148,
#     'radius': 5,
#     'color': '#79aaa0'},
#    {'id': 15,
#     'x': 334.5244074658354,
#     'y': 315.0899779178775,
#     'x_canvas': 334.5244074658354,
#     'y_canvas': 315.0899779178775,
#     'radius': 5,
#     'color': '#79aaa0'},
#    {'id': 16,
#     'x': 455.9277307192231,
#     'y': 410.29100727518943,
#     'x_canvas': 455.9277307192231,
#     'y_canvas': 410.29100727518943,
#     'radius': 5,
#     'color': '#79aaa0'},
#    {'id': 17,
#     'x': 352.7519852516553,
#     'y': 424.8813781040981,
#     'x_canvas': 352.7519852516553,
#     'y_canvas': 424.8813781040981,
#     'radius': 5,
#     'color': '#79aaa0'},
#    {'id': 18,
#     'x': 318.1613873393187,
#     'y': 322.59540365707375,
#     'x_canvas': 318.1613873393187,
#     'y_canvas': 322.59540365707375,
#     'radius': 5,
#     'color': '#79aaa0'},
#    {'id': 19,
#     'x': 344.77246147049186,
#     'y': 386.61178615476933,
#     'x_canvas': 344.77246147049186,
#     'y_canvas': 386.61178615476933,
#     'radius': 5,
#     'color': '#79aaa0'},
#    {'id': 20,
#     'x': 308.4418709772584,
#     'y': 331.6891933153957,
#     'x_canvas': 308.4418709772584,
#     'y_canvas': 331.6891933153957,
#     'radius': 5,
#     'color': '#79aaa0'},
#    {'id': 21,
#     'x': 366.6407909648959,
#     'y': 423.6942427664254,
#     'x_canvas': 366.6407909648959,
#     'y_canvas': 423.69424276642536,
#     'radius': 5,
#     'color': '#79aaa0'},
#    {'id': 22,
#     'x': 308.4837485711822,
#     'y': 344.5442181677791,
#     'x_canvas': 308.4837485711822,
#     'y_canvas': 344.5442181677791,
#     'radius': 5,
#     'color': '#79aaa0'},
#    {'id': 23,
#     'x': 354.1310262812887,
#     'y': 295.50459601658406,
#     'x_canvas': 354.1310262812887,
#     'y_canvas': 295.50459601658406,
#     'radius': 5,
#     'color': '#79aaa0'},
#    {'id': 24,
#     'x': 406.2310558301453,
#     'y': 301.9640324350105,
#     'x_canvas': 406.2310558301453,
#     'y_canvas': 301.9640324350105,
#     'radius': 5,
#     'color': '#79aaa0'},
#    {'id': 25,
#     'x': 387.3529397943895,
#     'y': 289.3105890424891,
#     'x_canvas': 387.3529397943895,
#     'y_canvas': 289.3105890424891,
#     'radius': 5,
#     'color': '#79aaa0'},
#    {'id': 26,
#     'x': 314.88056137586807,
#     'y': 306.0420032879424,
#     'x_canvas': 314.88056137586807,
#     'y_canvas': 306.0420032879424,
#     'radius': 5,
#     'color': '#79aaa0'},
#    {'id': 27,
#     'x': 375.0944370644986,
#     'y': 316.77770368458397,
#     'x_canvas': 375.09443706449866,
#     'y_canvas': 316.77770368458397,
#     'radius': 5,
#     'color': '#79aaa0'},
#    {'id': 28,
#     'x': 377.3181678433455,
#     'y': 341.25267572194133,
#     'x_canvas': 377.3181678433455,
#     'y_canvas': 341.25267572194133,
#     'radius': 5,
#     'color': '#79aaa0'},
#    {'id': 29,
#     'x': 329.3758212401565,
#     'y': 296.13508464012483,
#     'x_canvas': 329.3758212401565,
#     'y_canvas': 296.13508464012483,
#     'radius': 5,
#     'color': '#79aaa0'},
#    {'id': 30,
#     'x': 317.62371745682424,
#     'y': 375.42117136077803,
#     'x_canvas': 317.62371745682424,
#     'y_canvas': 375.42117136077803,
#     'radius': 5,
#     'color': '#79aaa0'},
#    {'id': 31,
#     'x': 391.20661655554864,
#     'y': 330.4099908785663,
#     'x_canvas': 391.20661655554864,
#     'y_canvas': 330.4099908785663,
#     'radius': 5,
#     'color': '#79aaa0'},
#    {'id': 32,
#     'x': 331.4952841773751,
#     'y': 337.5230742386089,
#     'x_canvas': 331.4952841773751,
#     'y_canvas': 337.5230742386089,
#     'radius': 5,
#     'color': '#79aaa0'},
#    {'id': 33,
#     'x': 345.18180628183575,
#     'y': 334.4909916205386,
#     'x_canvas': 345.18180628183575,
#     'y_canvas': 334.4909916205386,
#     'radius': 5,
#     'color': '#79aaa0'}]},
#  {'zoom': 1,
#   'node_charge': -45,
#   'node_gravity': 0.1,
#   'link_distance': 15,
#   'link_distance_variation': 0,
#   'node_collision': True,
#   'wiggle_nodes': False,
#   'freeze_nodes': False,
#   'node_fill_color': '#79aaa0',
#   'node_stroke_color': '#555555',
#   'node_label_color': '#000000',
#   'display_node_labels': False,
#   'scale_node_size_by_strength': False,
#   'node_size': 5,
#   'node_stroke_width': 1,
#   'node_size_variation': 0.5,
#   'link_color': '#7c7c7c',
#   'link_width': 2,
#   'link_alpha': 0.5,
#   'link_width_variation': 0.5,
#   'display_singleton_nodes': True,
#   'min_link_weight_percentile': 0,
#   'max_link_weight_percentile': 1})

# %%
import matplotlib.pyplot as plt
import networkx as nx
import netwulf as nw

G = nx.karate_club_graph()
dict = nx.get_node_attributes(G,'club')
nx.set_node_attributes(G,dict,"group")
results = nw.visualize(G)

# %%
def compute_modularity(G, partition):
    m = G.number_of_edges()
    Q = 0
    for c in set(partition.values()):
        Lc = [(i, j) for i, j in G.edges() if partition[i] == c and partition[j] == c]
        k_c = sum([G.degree[i] for i in G.nodes() if partition[i] == c])
        L = [(i, j) for i, j in G.edges()]
        Q += len(Lc)/len(L) - (k_c/(2*len(L)))**2
    return Q

# %% [markdown]
# Modularity is a measure of the quality of a partitioning of a network into communities or modules. It compares the number of edges within communities to the expected number of edges if the network were randomly wired. The higher the modularity score, the better the partitioning. It ranges from -1 to 1, where a score of 1 indicates a perfect partitioning and a score of 0 indicates a random partitioning. (edit)

# %%
#Q4
partition = nx.get_node_attributes(G, 'club')
modularity = compute_modularity(G, partition)
print(f"The modularity of the Karate Club split partitioning is {modularity}")
# Out:
# The modularity of the Karate Club split partitioning is 0.3582347140039447

# %%
#Q5
import random
import copy

def double_edge_swap(G):
    N = len(G.edges()) # number of edges in the network
    """
    This function creates a new network by swapping edges in the original network.
    G: the original network
    N*1.4: the number of swaps
    """
    G_new = copy.deepcopy(G) # create an identical copy of the original network
    nodes = list(G.nodes()) # list of nodes in the network

    for i in range(int(N*2.1)):
        edges = list(G_new.edges()) # list of edges in the network
        # choose two random edges
        e1, e2 = random.sample(edges, 2)
        u, v = e1
        x, y = e2

        # make sure the chosen edges are not adjacent
        
        if (u != v) and (v != x) and (v != y) and (u != x) and (u != y) and (x != y) and (u, y) not in edges and (x, v) not in edges and (y, u) not in edges and (v, x) not in edges:
            # add the new edges and remove the old ones
            G_new.add_edge(u, y)
            G_new.add_edge(x, v)
            G_new.remove_edge(u, v)
            G_new.remove_edge(x, y)
            if len(G_new.edges()) != len(G.edges()):
                print(e1)
                print(e2)
                print(edges)
                
    
    if len(G_new.edges()) != len(G.edges()):
        print(len(G_new.edges()))
        print(len(G.edges()))
        raise ValueError("degree of nodes in the OG network and rand version are not the same")
    return G_new

# %%
partition = nx.get_node_attributes(G, 'club')
modularities = []
for i in range(1000):
    G_new = double_edge_swap(G)
    modularities.append(compute_modularity(G_new,partition))

# %%
modularities = np.array(modularities)
modularities_std = np.std(modularities)
modularities_mean = np.mean(modularities)
print(f"modularities std = {modularities_std}")
print(f"modularities mean = {modularities_mean}")
# Out:
# modularities std = 0.04576841197285269
# modularities mean = -0.009278106508875806

# %% [markdown]
# Conclusion:

# %%
matplotlib.pyplot.axvline(x=0, ymin=0, ymax=1, **kwargs)

# %%
fig, ax = plt.subplots()
bins = np.arange(-0.2, 0.4, 0.01)
ax.hist(modularities, bins=bins)
ax.axvline(x=modularity, color='r')
ax.set_xlabel("Modularity")
ax.set_ylabel("Frequency")
ax.set_title("Randomized Modularity Distribution")
plt.show()

# %%
import community as community_louvain
partition = community_louvain.best_partition(G)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[264], line 2
#       1 import community as community_louvain
# ----> 2 partition = community_louvain.best_partition(G)
#
# AttributeError: module 'community' has no attribute 'best_partition'

# %%
nx.louvain_communities(G)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[269], line 1
# ----> 1 nx.louvain_communities(G)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\networkx\__init__.py:51, in __getattr__(name)
#      42 if name == "write_yaml":
#      43     raise ImportError(
#      44         "\nwrite_yaml has been removed from NetworkX, please use `yaml`\n"
#      45         "directly:\n\n"
#    (...)
#      49         "This message will be removed in NetworkX 3.0."
#      50     )
# ---> 51 raise AttributeError(f"module {__name__} has no attribute {name}")
#
# AttributeError: module networkx has no attribute louvain_communities

# %%
# Out:
# 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\community\\__init__.py'
